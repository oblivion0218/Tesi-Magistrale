# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
from scipy.ndimage import gaussian_filter
from matplotlib.lines import Line2D
import os

# --- 1. PARAMETRI FISICI ---
S = 2.02e17
E_f_joule = 200.0 * 1e6 * 1.6022e-19

# --- 2. LETTURA DATI ---
FILE_IN = 'result_fixed_old.txt'

pitches = []
mixes = []
fissions = []

if os.path.exists(FILE_IN):
    with open(FILE_IN, 'r') as f:
        for line in f:
            parts = line.split()
            if len(parts) >= 3 and parts[0].replace('.', '', 1).isdigit():
                pitches.append(float(parts[0]))
                mixes.append(float(parts[1]))
                fissions.append(float(parts[2]))

pitches = np.array(pitches)
mixes = np.array(mixes)
fissions = np.array(fissions)

# --- 3. CALCOLO POTENZA TERMICA [MW] E PUNTI NOTEVOLI ---
tasso_fissione = fissions * S
potenza_termica_MW = (tasso_fissione * E_f_joule) / 1e6

idx_max = np.argmax(potenza_termica_MW)
idx_min = np.argmin(potenza_termica_MW)

p_max = potenza_termica_MW[idx_max]
p_min = potenza_termica_MW[idx_min]
pitch_max, mix_max = pitches[idx_max], mixes[idx_max]
pitch_min, mix_min = pitches[idx_min], mixes[idx_min]

# --- 4. PREPARAZIONE DATI PER IL PLOT 3D ---
grid_x, grid_y = np.mgrid[min(pitches):max(pitches):100j, min(mixes):max(mixes):100j]
grid_z = griddata((pitches, mixes), potenza_termica_MW, (grid_x, grid_y), method='linear')

# Gestione NaN e Smoothing Gaussiano
nan_mask = np.isnan(grid_z)
grid_z_filled = np.nan_to_num(grid_z, nan=np.nanmean(grid_z))
grid_z = gaussian_filter(grid_z_filled, sigma=3) 
grid_z[nan_mask] = np.nan

# --- 5. CREAZIONE E FORMATTAZIONE DEL PLOT ---
fig = plt.figure(figsize=(16, 10))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(grid_x, grid_y, grid_z, cmap="viridis", edgecolor='none', alpha=0.7)
ax.contour(grid_x, grid_y, grid_z, zdir='z', offset=np.nanmin(grid_z), cmap="viridis", alpha=0.5)

# Formattazione Assi e Titoli (Stile Unificato)
ax.set_title(r"Mappa di Ottimizzazione 3D: $P_{termica}(Pitch, Mix)$", 
             fontsize=16, fontweight='bold', color='#2F4F4F', pad=25)
ax.set_xlabel(r"Moltiplicatore Pitch", fontsize=14, fontweight='bold', color='#2F4F4F', labelpad=15)
ax.set_ylabel(r"Frazione Vol. Acqua", fontsize=14, fontweight='bold', color='#2F4F4F', labelpad=15)
ax.set_zlabel(r"Potenza Termica [MW]", fontsize=14, fontweight='bold', color='#2F4F4F', labelpad=15)

# Impostazioni Griglia (Stile Unificato)
for axis in [ax.xaxis, ax.yaxis, ax.zaxis]:
    axis._axinfo["grid"].update({"color": "#778899", "linestyle": "--", "alpha": 0.6})

# Trasparenza pannelli di fondo
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))


plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# --- 1. PARAMETRI FISICI ---
S = 2.02e17
E_f_joule = 200.0 * 1e6 * 1.6022e-19

# --- 2. LETTURA DATI ---
FILE_IN = 'result_fixed_old.txt'

pitches = []
mixes = []
fissions = []

if os.path.exists(FILE_IN):
    with open(FILE_IN, 'r') as f:
        for line in f:
            parts = line.split()
            if len(parts) >= 3 and parts[0].replace('.', '', 1).isdigit():
                pitches.append(float(parts[0]))
                mixes.append(float(parts[1]))
                fissions.append(float(parts[2]))

# Creazione DataFrame
df = pd.DataFrame({
    'Pitch': pitches,
    'Mix': mixes,
    'Fissions': fissions
})

# --- 3. CALCOLO POTENZA TERMICA [MW] ---
df['Potenza_MW'] = (df['Fissions'] * S * E_f_joule) / 1e6

# --- 4. PREPARAZIONE MATRICE DATI ---
# Trasforma i dati in una matrice 2D per la heatmap. 
# Se i punti non sono una griglia perfetta, la pivot_table media i valori sovrapposti.
heatmap_data = df.pivot_table(index='Mix', columns='Pitch', values='Potenza_MW')

# Opzionale: inverte l'asse Y per avere i valori minori in alto (come nell'immagine di riferimento)
heatmap_data = heatmap_data.sort_index(ascending=False)

# --- 5. CREAZIONE E FORMATTAZIONE DEL PLOT ---
fig, ax = plt.subplots(figsize=(16, 10))

# Generazione Heatmap
# annot=True mostra i valori nelle celle, fmt imposta i decimali
sns.heatmap(heatmap_data, annot=True, fmt=".2f", cmap="viridis", 
            cbar_kws={'label': r'$P_{termica}$ [MW]'}, ax=ax)

# Formattazione Assi e Titoli (Stile Unificato)
ax.set_title(r"Mappa di Potenza Termica: $P_{termica}(\text{Pitch}, \text{Mix})$", 
             fontsize=16, fontweight='bold', color='#2F4F4F', pad=25)
ax.set_xlabel(r"Moltiplicatore Pitch", fontsize=14, fontweight='bold', color='#2F4F4F', labelpad=15)
ax.set_ylabel(r"Frazione Vol. Acqua", fontsize=14, fontweight='bold', color='#2F4F4F', labelpad=15)

# Formattazione colorbar
cbar = ax.collections[0].colorbar
cbar.ax.yaxis.label.set_fontsize(12)
cbar.ax.tick_params(labelsize=12)

plt.tight_layout()
plt.show()
